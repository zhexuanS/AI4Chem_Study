# %% [markdown]
# <a href="https://colab.research.google.com/github/schwallergroup/ai4chem_course/blob/main/notebooks/04%20-%20Unsupervised%20Learning/palladium_dimers_discovery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Accelerating palladium catalyst discovery: a practical application of unsupervised learning
#
# ## Table of content
#
# 1. Problem introduction
# 2. General clustering
# 3. DFT-specific descriptors
# 4. Final Clustering
# 5. Experimental validation

# %% [markdown]
# In this tutorial we will see how a simple algorithm like k-means can be used to discover new catalysts using few experimental data to guide the next experiments. We will see how a clever use of ML-techniques is able to reveal unintuitive patterns and suggest experiments that would be otherwise ignored.
#
# The notebook is based on the work of Hueffel et al. and was published in this [Science](https://www.science.org/doi/full/10.1126/science.abj0999) article in 2021.

# %% [markdown]
# # 0. Relevant packages

# %% [markdown]
# Install usual packages and download the datasets.

# %%
! pip install scikit-learn pandas numpy matplotlib seaborn scipy tqdm

! mkdir data
! wget https://raw.githubusercontent.com/schwallergroup/ai4chem_course/main/notebooks/04%20-%20Unsupervised%20Learning/data/LKB_P.csv -O data/LKB_P.csv
! wget https://raw.githubusercontent.com/schwallergroup/ai4chem_course/main/notebooks/04%20-%20Unsupervised%20Learning/data/Dimer_LKB_P.csv -O data/Dimer_LKB_P.csv
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# --2025-08-06 14:28:31--  https://raw.githubusercontent.com/schwallergroup/ai4chem_course/main/notebooks/04%20-%20Unsupervised%20Learning/data/LKB_P.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70133 (68K) [text/plain]
# Saving to: ‘data/LKB_P.csv’
#
# data/LKB_P.csv      100%[===================>]  68.49K  --.-KB/s    in 0.1s
#
# 2025-08-06 14:28:32 (677 KB/s) - ‘data/LKB_P.csv’ saved [70133/70133]
#
# --2025-08-06 14:28:32--  https://raw.githubusercontent.com/schwallergroup/ai4chem_course/main/notebooks/04%20-%20Unsupervised%20Learning/data/Dimer_LKB_P.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39912 (39K) [text/plain]
# Saving to: ‘data/Dimer_LKB_P.csv’
#
# data/Dimer_LKB_P.cs 100%[===================>]  38.98K  --.-KB/s    in 0.05s
#
# 2025-08-06 14:28:33 (743 KB/s) - ‘data/Dimer_LKB_P.csv’ saved [39912/39912]

# %% [markdown]
# # 1. Problem introduction

# %% [markdown]
# `Metal speciation` (the distribution of a metal in different physical and chemical forms) is a key property in homogeneous catalysis. This feature plays a crucial role in determining catalyst properties like reactivity or selectivity. Ligands are one of the factors related to metal speciation. Despite the common assumption that structure and reactvity are correlated, the impact of the ligand on catalytic activity is not fully understood, hampering the design of new catalysts.
#
# <div align="left">
# <img src="https://github.com/schwallergroup/ai4chem_course/blob/main/notebooks/04%20-%20Unsupervised%20Learning/img/speciation.png?raw=1" width="400"/>
# </div>
#
# Palladium-catalyzed reactions are one of the most representative transformations involving homogeneous catalysts. Despite the majority of catalytic cycles involve Pd(0) and Pd(II) species, Pd(I) dimers with the [Pd(I)(&mu;-X)P(t-Bu)<sub>3</sub>]<sub>2</sub> motif are specially interesting due to their stability and catalytic performance. However, it is not fully understood why certain ligands favor Pd(I) dimers while others do not, so only few examples of this type of compounds were known.
#
# <div align="left">
# <img src="https://github.com/schwallergroup/ai4chem_course/blob/main/notebooks/04%20-%20Unsupervised%20Learning/img/pd.png?raw=1" width="400"/>
# </div>
#
# The common strategy to discover new species is trial and error. Only 4 ligands promoting Pd(I) state had been discovered using this approach. Different attempts to overcome these limitations were tried. PCA decomposition using 28 general descriptors from a set of 348 monodentate phospine ligands was not able to derive ligand-speciation relationships. On the other hand, DFT calculation of the coprorportionation energy of Pd(0) with Pd(II) to Pd(I) suggested that high exergonicity was related to Pd(I) formation. However, the associated energy of PdCy<sub>3</sub> (non-inducing Pd(I) ligand) was rougly the same than the known Pd(I)-inducing phosphines, thus invalidating this hypothesis.
#
# <div align="left">
# <img src="https://github.com/schwallergroup/ai4chem_course/blob/main/notebooks/04%20-%20Unsupervised%20Learning/img/PdDFT.png?raw=1" width="400"/>
# </div>
#
# Given the few experimental points we have, *could we use unsupervised learning to leverage this knowledge and propose new candidate ligands for Pd(I) dimers discovery?*

# %% [markdown]
# ## Exercise 1
# As a first exercise, we will load the dataframe containing the 348 phosphine ligands and the general descriptors. Each molecule is also classified in one of 8 categories describing the type of ligand. The first 4 principal components of the data are also included. We will verify that PCA is unable to give good insight to the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load ligand information
ligands = pd.read_csv('data/LKB_P.csv', sep=';')

ligands.head()
# Out:
#    No. Type  E(HOMO)  E(LUMO)  He8_steric      PA   Q(B)  BE(B)    P-B  \
# 0    1    R -0.24636 -0.00029        2.30  190.60 -0.590  26.10  1.941
# 1    2    R -0.19045  0.03268        3.00  233.00 -0.680  39.20  1.926
# 2    3    R -0.27742 -0.05837        3.00  182.30 -0.560  26.30  1.915
# 3    4    R -0.26620 -0.11270       20.66  194.04 -0.538  22.51  1.924
# 4    5    R -0.18723  0.02584        6.00  239.10 -0.680  39.00  1.934
#
#    DP-A(B)  ...  BE(Pt)   P-Pt  DP-A(Pt)  DA-P-A(Pt)  <(H3P)Pt(PH3)   S4'  \
# 0   -0.013  ...    8.80  2.328    -0.001         1.5          109.4  66.9
# 1   -0.028  ...   12.90  2.331    -0.010         1.3          107.5  39.4
# 2   -0.002  ...   22.80  2.250     0.008        -0.1          109.0  52.2
# 3   -0.005  ...   16.58  2.260     0.046        -2.4          106.6  28.7
# 4   -0.027  ...   17.10  2.338    -0.010         1.6          107.4  39.0
#
#      PC1    PC2    PC3    PC4
# 0 -3.078  0.798  6.079 -1.066
# 1  1.602  3.976  1.536  0.090
# 2 -7.226 -3.302  2.929  2.032
# 3 -6.715 -9.291  1.348 -0.823
# 4  2.280  3.408  1.584  0.168
#
# [5 rows x 34 columns]

# %% [markdown]
# Now, plot the ligands using PC1 and PC2, displaying also the ligand label (from the 'Type' column).

# %%
import seaborn as sns
sns.scatterplot(data=ligands, x='PC1', y='PC2', hue='Type');

# %% [markdown]
# Verify that the PCA decomposition is unable to separate Pd(I) inducing ligands from the non-inducing ligand. For this purpose, plot the dataset again and remark the datapoints that correspond to the target ligands.

# %%
#These are the indices of the positive (Pd(I) inducing) and negative ligands
pos_refs = [16, 41, 54, 113]
neg_refs = [21]

sns.scatterplot(data=ligands, x='PC1', y='PC2', hue='Type');

#Get the coordinates of positive and negative references
pos_refs_x = ligands.loc[pos_refs, 'PC1']
pos_refs_y = ligands.loc[pos_refs, 'PC2']
neg_refs_x = ligands.loc[neg_refs, 'PC1']
neg_refs_y = ligands.loc[neg_refs, 'PC2']

# plot the points in pos_refs and neg_refs with different marker style
plt.scatter(pos_refs_x, pos_refs_y, marker='o', edgecolors='black', linewidths=2, s=150, facecolors='none')
plt.scatter(neg_refs_x, neg_refs_y, marker='s', edgecolors='black', linewidths=2, s=150, facecolors='none')

plt.xlim(-2,7)
plt.ylim(-4,4)
# show the plot
plt.show()

# %% [markdown]
# You can clearly see how we are not able to extract clear information from PCA. Two of the Pd(I)-inducing ligands are closer to the non-inducing ligand than to the other known ligands, indicating that this analysis is not enough to suggest new species.

# %% [markdown]
# # 2. General property clustering

# %% [markdown]
# Time to change the approach! First, we will see if k-means algorithm is able to cluster our ligands efficiently. This will allow us to reduce the number of possible molecules we have to consider for experimental screening.

# %% [markdown]
# Try to run a k-Means clustering on the data using different values of k and select the best parameters based on the inertia, distorition and silhouette score.

# %%
import numpy as np

from tqdm import tqdm

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from scipy.spatial.distance import cdist
from sklearn import preprocessing

def min_max_scale(X):
    """
    Scale each column in the provided pd.DataFrame to values between 0 and 1.
    :param X:   (pd.DataFrame)  The data to process.
    :return:    (pd.DataFrame)  The processed data.
    """
    scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
    X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)
    return X


def standard_scale(X):
    """
    Standardize each column in the provided pd.DataFrame.
    :param X:   (pd.DataFrame)  The data to process.
    :return:    (pd.DataFrame)  The processed data.
    """
    scaler = preprocessing.StandardScaler()
    X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)
    return X


class KMeansModel:

    def __init__(self, X, k=8, rs=1):
        """
        Wrapper for the sklearn.KMeans algorithm that extracts relevant information.. Provides functionality to optimize
        and build the model.
        :param X:   (pd.DataFrame) The (processed) input data for the model. Needs to be provided as a pandas.DataFrame.
                                   Ideally, the index of the DataFrame refers to the identifiers within the data set.
        :param k:   (int) Cluster number to be used for the kmeans algorithm. Default: 8.
        :param rs:  (int) Random state to be used for the model. Default: 1
        """
        self.X = X
        self.k = k
        self.rs = rs

        # Storage for model
        self.model = None

        # Storage for results
        self.clusters = pd.DataFrame()

        # Storage for evaluation metrics
        self.inert = float  # Inertia
        self.dist = float  # Distortion
        self.sil = float  # Average Silhouette Score
        self.sil_sample = None  # Silhouette Score per sample

    def run(self):
        """
        Run the kmeans algorithm on the given data set with a given cluster number k and a given random state.
        """
        self.model = KMeans(n_clusters=self.k, n_init=10, init="k-means++", random_state=self.rs)
        self.model.fit(self.X)

        self.clusters = pd.DataFrame({"Cluster": self.model.labels_}, index=self.X.index)
        self.inert = float(self.model.inertia_)
        self.dist = float(sum(np.min(cdist(self.X.to_numpy(), self.model.cluster_centers_, 'euclidean'), axis=1)) /
                          self.X.shape[0])
        self.sil = float(silhouette_score(self.X.to_numpy(), self.model.labels_))
        self.sil_sample = silhouette_samples(self.X.to_numpy(), self.model.labels_)

    def opt(self, ks):
        """
        Find the optimal cluster number k from a list of different ks.
        :param ks:  (list) Values for k that should be checked during the optimization.
        :return:    metrics (pd.DataFrame): Inertia, Distortion and Average Silhouette scores for each value of k
                    clusters (pd.DataFrame): The resulting clusters for each value of k.
                    sil_samples (pd.DataFrame): Per sample silhouette score for each value of k.
        """
        metrics = pd.DataFrame(columns=["Inertia", "Distortion", "Silhouette"])
        metrics.index.name = "k"

        clusters = pd.DataFrame(index=self.X.index)
        clusters.index.name = self.X.index.name
        sil_samples = pd.DataFrame(index=self.X.index)
        sil_samples.index.name = self.X.index.name

        for k in tqdm(ks):
            self.k = k
            self.run()
            metrics.at[k, "Inertia"] = self.inert
            metrics.at[k, "Distortion"] = self.dist
            metrics.at[k, "Silhouette"] = self.sil

            clusters[f"k={k}"] = self.clusters.to_numpy().flatten()
            sil_samples[f"k={k}"] = self.sil_sample

        return metrics, clusters, sil_samples

    def stats(self, ref_ids, k=None, rs_range=None):
        """
        Investigate the dependency of the resulting clusters on different random_states. The function runs the k-means
        algorithm for each provided random state and checks how often each instance is grouped with the provided
        reference instances and calculates a normalized score.
        :param ref_ids:     (list) List of indices of the references, for which the similarity to other instances in the
                            data should be evaluated. The indices must correspond to the index in self.X!
        :param k:           (int) Cluster number k. Default: None (= use the value stored in self.k)
        :param rs_range:    (list) List of random states that should be checked. Default: None (= use range(0, 1000))
        :return:    stats (pd.DataFrame)    Table containing information on whether an instance was grouped with the
                                            references or not when using the provided random states (One-Hot-Encoded).
                                            The last column ("Score") contains the percentage of times the instance was
                                            grouped with the references.
        """
        # Range of random states to check
        rs_range = range(0, 1000) if rs_range is None else rs_range

        # Set the value for k, if provided
        self.k = k if k is not None else self.k

        # Storage
        stats = pd.DataFrame(index=self.X.index)

        # For each random state ...
        for rs in tqdm(rs_range):
            # Define a column name
            col = f"RS{rs}"
            # Run the model
            self.rs = rs
            self.run()
            # Report the resulting clusters
            stats[col] = self.clusters.to_numpy().flatten()
            # Get the clusters that contain references
            ref_cluster = list(set(stats.loc[stats.index.isin(ref_ids)][col]))
            # Get all members within these clusters
            ref_cluster_members = list(stats.loc[stats[col].isin(ref_cluster)].index)
            # One Hot Encode the results (1: instance was clustered with refs, 0: instance was not clustered with refs)
            for idx in stats.index:
                stats.at[idx, col] = 1 if idx in ref_cluster_members else 0

        # Get the total number of times a ligand was clustered with the references
        stats["Sum"] = stats.sum(axis=1)
        # Calculate percentage (= Score)
        stats["Score"] = stats["Sum"] / len(rs_range)

        return stats

# %%
# Load data and standardize it
process = ['E(HOMO)', 'E(LUMO)', 'He8_steric', 'PA', 'Q(B)', 'BE(B)', 'P-B', 'DP-A(B)', 'DA-P-A(B)', 'Q(Au)', 'BE(Au)',
           'Au-Cl', 'Au-P', 'DP-A(Au)', 'DA-P-A(Au)', 'Q(Pd)', 'BE(Pd)', 'Pd-Cl trans', 'P-Pd', 'DP-A(Pd)',
           'DA-P-A(Pd)', 'Q(Pt)', 'BE(Pt)', 'P-Pt', 'DP-A(Pt)', 'DA-P-A(Pt)', '<(H3P)Pt(PH3)', "S4'"]
# Columns in the data set to exclude from clustering
drop = ['Type', "PC1", "PC2", "PC3", "PC4"]


# Data preprocessing
X = standard_scale(ligands.drop(columns=drop))

#Initialize model
model = KMeansModel(X=X, k=8, rs=1)

# Run the optimization and get metrics, clusters and per sample silhouette scores for each value of k
metrics, clusters, sil_samples = model.opt(ks=range(2, 15))
# Out:
# 100%|██████████| 13/13 [00:00<00:00, 15.66it/s]

# %% [markdown]
# Plot metrics to select the best k based on this analysis.

# %%
### YOUR CODE
fig, axes = plt.subplots(1, 3, figsize=(14,4))

for i, metric in enumerate(metrics.columns):

    y = metrics[metric].values
    x = metrics.index
    axes[i].plot(x,y)
    axes[i].set_title(metric)
    axes[i].set_xlabel('k')
plt.show()

# %% [markdown]
# The inertia and distortin method do not suggest a clear k. Silhouette method may suggest an optimal k around 7.

# %% [markdown]
# ## Optional
#
# In the original publication, they choose an optimal number of clusters equal to 8 (due to the similar scores achieved by k between 6 and 8 and the fact that the original classes of ligands was 8). Build a k-Means model with k=8 and fit it with 1000 different random seeds. Then, count how many times each ligand is grouped in the same cluster of the positive (Pd(I)-inducing) ligands.

# %%
## YOUR CODE
#Initialize
best_model = KMeansModel(X=X, k=8, rs=1)

# Run the model
best_model.run()

#Run the algorithm
stats = best_model.stats(ref_ids=pos_refs, k=8)
# Out:
#  10%|▉         | 99/1000 [00:08<01:00, 14.95it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  10%|█         | 101/1000 [00:08<00:59, 15.01it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  10%|█         | 103/1000 [00:08<01:00, 14.86it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  10%|█         | 105/1000 [00:08<00:59, 14.93it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  11%|█         | 107/1000 [00:08<00:59, 15.11it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  11%|█         | 109/1000 [00:08<01:02, 14.32it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  11%|█         | 111/1000 [00:08<01:01, 14.36it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  11%|█▏        | 113/1000 [00:09<01:02, 14.28it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  12%|█▏        | 115/1000 [00:09<01:01, 14.47it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  12%|█▏        | 117/1000 [00:09<01:01, 14.34it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  12%|█▏        | 119/1000 [00:09<01:01, 14.29it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  12%|█▏        | 121/1000 [00:09<01:00, 14.45it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  12%|█▏        | 123/1000 [00:09<01:03, 13.75it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  12%|█▎        | 125/1000 [00:09<01:03, 13.67it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  13%|█▎        | 127/1000 [00:10<01:03, 13.72it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  13%|█▎        | 129/1000 [00:10<01:02, 14.03it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  13%|█▎        | 131/1000 [00:10<01:01, 14.06it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  13%|█▎        | 133/1000 [00:10<01:01, 14.09it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  14%|█▎        | 135/1000 [00:10<01:01, 14.10it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  14%|█▎        | 137/1000 [00:10<01:02, 13.82it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  14%|█▍        | 139/1000 [00:10<01:02, 13.72it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  14%|█▍        | 141/1000 [00:11<01:02, 13.81it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  14%|█▍        | 143/1000 [00:11<01:01, 13.99it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  14%|█▍        | 145/1000 [00:11<01:01, 14.00it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  15%|█▍        | 147/1000 [00:11<01:00, 14.00it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  15%|█▍        | 149/1000 [00:11<01:01, 13.94it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  15%|█▌        | 151/1000 [00:11<01:00, 14.02it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  15%|█▌        | 153/1000 [00:12<01:05, 12.99it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▌        | 155/1000 [00:12<01:15, 11.17it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▌        | 157/1000 [00:12<01:32,  9.09it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▌        | 159/1000 [00:13<02:01,  6.94it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▌        | 160/1000 [00:13<02:09,  6.48it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▌        | 161/1000 [00:13<02:06,  6.65it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▌        | 162/1000 [00:13<02:24,  5.80it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▋        | 163/1000 [00:13<02:47,  4.99it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▋        | 164/1000 [00:14<03:06,  4.48it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▋        | 165/1000 [00:14<03:07,  4.44it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  17%|█▋        | 166/1000 [00:14<03:07,  4.45it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  17%|█▋        | 167/1000 [00:14<02:53,  4.80it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  17%|█▋        | 168/1000 [00:14<02:39,  5.21it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  17%|█▋        | 170/1000 [00:15<01:59,  6.97it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  17%|█▋        | 172/1000 [00:15<01:35,  8.65it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  17%|█▋        | 174/1000 [00:15<01:23,  9.89it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  18%|█▊        | 176/1000 [00:15<01:16, 10.78it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  18%|█▊        | 178/1000 [00:15<01:12, 11.35it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  18%|█▊        | 180/1000 [00:15<01:12, 11.26it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  18%|█▊        | 182/1000 [00:16<01:12, 11.28it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  18%|█▊        | 184/1000 [00:16<01:14, 10.94it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▊        | 186/1000 [00:16<01:31,  8.85it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▉        | 188/1000 [00:16<01:32,  8.77it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▉        | 189/1000 [00:16<01:35,  8.50it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▉        | 190/1000 [00:17<01:42,  7.91it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▉        | 191/1000 [00:17<01:54,  7.06it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▉        | 192/1000 [00:17<01:55,  7.01it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▉        | 193/1000 [00:17<02:01,  6.63it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▉        | 194/1000 [00:17<01:58,  6.82it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|█▉        | 195/1000 [00:17<02:00,  6.68it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|█▉        | 196/1000 [00:18<02:06,  6.35it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|█▉        | 197/1000 [00:18<01:54,  7.04it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|█▉        | 198/1000 [00:18<02:08,  6.25it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|█▉        | 199/1000 [00:18<01:55,  6.95it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|██        | 200/1000 [00:18<01:58,  6.75it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|██        | 201/1000 [00:18<01:58,  6.76it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|██        | 202/1000 [00:18<01:53,  7.02it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|██        | 203/1000 [00:19<02:03,  6.45it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|██        | 205/1000 [00:19<01:45,  7.56it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██        | 206/1000 [00:19<01:58,  6.69it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██        | 207/1000 [00:19<02:11,  6.05it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██        | 208/1000 [00:19<02:15,  5.86it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██        | 209/1000 [00:20<02:11,  6.01it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██        | 210/1000 [00:20<02:50,  4.62it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██        | 211/1000 [00:20<03:02,  4.31it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██        | 212/1000 [00:20<02:48,  4.67it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██▏       | 213/1000 [00:21<02:51,  4.58it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██▏       | 214/1000 [00:21<02:50,  4.61it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  22%|██▏       | 215/1000 [00:21<02:56,  4.44it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  22%|██▏       | 216/1000 [00:21<02:58,  4.39it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  22%|██▏       | 217/1000 [00:22<03:01,  4.31it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  22%|██▏       | 218/1000 [00:22<02:36,  4.99it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  22%|██▏       | 219/1000 [00:22<02:39,  4.91it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# ...
#   stats[col] = self.clusters.to_numpy().flatten()
#  96%|█████████▋| 964/1000 [02:02<00:04,  7.23it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  96%|█████████▋| 965/1000 [02:02<00:04,  7.65it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 966/1000 [02:02<00:04,  7.36it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 967/1000 [02:03<00:04,  7.50it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 968/1000 [02:03<00:04,  7.38it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 969/1000 [02:03<00:04,  6.82it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 970/1000 [02:03<00:04,  6.72it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 971/1000 [02:03<00:04,  6.99it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 972/1000 [02:03<00:03,  7.03it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 973/1000 [02:03<00:03,  6.97it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 974/1000 [02:04<00:03,  6.82it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 975/1000 [02:04<00:03,  6.62it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 976/1000 [02:04<00:04,  5.06it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 977/1000 [02:04<00:04,  5.62it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 978/1000 [02:04<00:03,  5.80it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 979/1000 [02:05<00:03,  6.19it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 980/1000 [02:05<00:03,  6.36it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 981/1000 [02:05<00:02,  6.74it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 982/1000 [02:05<00:02,  6.52it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 983/1000 [02:05<00:02,  6.56it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 984/1000 [02:05<00:02,  6.79it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 985/1000 [02:05<00:02,  6.53it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▊| 986/1000 [02:06<00:02,  6.64it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▊| 987/1000 [02:06<00:02,  6.45it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▉| 988/1000 [02:06<00:01,  6.38it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▉| 989/1000 [02:06<00:01,  6.40it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▉| 990/1000 [02:06<00:01,  6.17it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▉| 991/1000 [02:06<00:01,  5.76it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▉| 992/1000 [02:07<00:01,  5.56it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▉| 993/1000 [02:07<00:01,  5.33it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▉| 994/1000 [02:07<00:01,  4.88it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# 100%|█████████▉| 995/1000 [02:07<00:01,  4.88it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# 100%|█████████▉| 996/1000 [02:07<00:00,  5.03it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# 100%|█████████▉| 997/1000 [02:08<00:00,  4.90it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# 100%|█████████▉| 998/1000 [02:08<00:00,  4.97it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# 100%|█████████▉| 999/1000 [02:08<00:00,  5.05it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# 100%|██████████| 1000/1000 [02:08<00:00,  7.76it/s]
# /tmp/ipython-input-612201913.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats["Sum"] = stats.sum(axis=1)
# /tmp/ipython-input-612201913.py:144: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats["Score"] = stats["Sum"] / len(rs_range)

# %% [markdown]
# This way we obtain a statistics dataframe that can be used to filter the ligands based on the Score (normalized number of times that a given ligand is clustered with the reference ligands). Take the ligands that are grouped with the positive group more than 75% of the time.

# %%
## YOUR CODE
#example, take only the ligands whose score is higher than 0.5 (select indices)
filtered = stats[stats['Score'] > 0.75].index

# %% [markdown]
# Visualize the indices of the clustered ligands and verify that number 21 (non-inducing ligand) is not included in this group. This array of indices can be used to select and filter the original data.

# %%
## YOUR CODE
filtered
# Out:
# Index([  7,  15,  16,  19,  26,  33,  40,  41,  44,  54,  55,  58,  60,  62,
#         63,  64,  65,  66,  67,  68,  70,  71,  72,  73,  74,  76,  78,  79,
#         81,  83,  86,  87,  88,  89,  90,  91,  93,  96,  97,  99, 102, 103,
#        105, 109, 113, 115, 119, 120, 122, 126, 127, 128, 129, 130, 131, 132,
#        133, 134, 135, 139, 140, 141, 152, 161, 164, 165, 167, 170, 171, 173,
#        175, 176, 178, 179, 180, 183, 185, 186, 270, 292, 297, 298, 302, 303,
#        309, 310, 311, 315, 316, 323, 325, 341, 342],
#       dtype='int64')

# %% [markdown]
# Check also that this group of ligands contains mixed ligand types.

# %%
## YOUR CODE
ligands['Type'][filtered].value_counts()
# Out:
# Type
# R           45
# Ar          37
# NR2/NAr2     8
# PABC         2
# CH2=CH2      1
# Name: count, dtype: int64

# %% [markdown]
# Great! We have got rid of the nasty non-inducing ligand. Besides, our selected cluster now contains different types of ligands. This is a good first step.

# %% [markdown]
# # 3. DFT-specific descriptors

# %% [markdown]
# The first clustering reduced the candidate ligands space to ~25% of the original size, keeping 89 ligands from the list of 348. A subsequent k-means clustering using the general descriptors in order to refine this first filtering failed. Therefore, the descriptors needed to be tuned for this specific problem. DFT-specific descriptors related to the Pd(I) iodine bridge were calculated and included in the dataset (a total of 42 new descriptors).
#
# We will not calculate all the DFT descriptors, but just load the dataset containing the refined ligands. This dataframe only contains 66 ligands as the calculations were only done for ligands containing P-C bonds.

# %%
#Load and visualize the dataframe containing DFT-specific descriptors (the Dimer_LKB_P.csv file)
## YOUR CODE
dimers = pd.read_csv('./data/Dimer_LKB_P.csv', sep=';')

dimers.head()
# Out:
#    No. Type  E(HOMO)  E(LUMO)  He8_steric      PA  Q(Pd)  BE(Pd)  Pd-Cl trans  \
# 0   15    R -0.17500  0.02350       37.82  247.52 -1.257   30.03        2.379
# 1   16    R -0.17267  0.02754       23.38  250.80 -1.200   23.90        2.382
# 2   19    R -0.18340  0.01900       31.31  243.63 -1.282   28.25        2.377
# 3   36    R -0.17840  0.02300       19.69  245.86 -1.275   34.79        2.379
# 4   37    R -0.17790  0.02220       18.53  246.58 -1.253   35.72        2.380
#
#     P-Pd  ...  G_NBO_Pd   G_NBO_P  G_LENGTH_Pd_P  G_LENGTH_Pd_Pd  \
# 0  2.337  ... -0.379685  1.297005       2.312152        3.226557
# 1  2.418  ... -0.278010  1.232615       2.413734        4.305073
# 2  2.308  ... -0.340260  1.205245       2.314010        3.620629
# 3  2.321  ... -0.365385  1.280040       2.317294        3.187955
# 4  2.334  ... -0.387150  1.284050       2.346424        3.102411
#
#    G_TORSION_Pd_I_I_Pd  G_ORDER_Pd_Pd      PC1'      PC2'      PC3'      PC4'
# 0           103.059842         0.1171 -0.986788  0.414056  0.017615 -0.632639
# 1           174.451579         0.0264  1.198717  1.162347  0.901051 -0.055612
# 2           124.149654         0.0713 -0.146169 -0.318877  0.877642 -0.227544
# 3           101.341176         0.1254 -1.135555  0.275201  0.181931 -0.516078
# 4            95.391197         0.1369 -0.904739  0.447820  0.106396 -0.301205
#
# [5 rows x 62 columns]

# %% [markdown]
# # 4. Final clustering: unraveling new ligands

# %% [markdown]
# Once the new descriptors were calculated, we can try a second k-Means clustering to see if we can reduce even more our candidate space. Repeat the same clusterig process to select the optimum k.

# %%
# Columns in the data set to exclude
drop = ["Type", "PC1", "PC2", "PC3", "PC4", "PC1'", "PC2'", "PC3'", "PC4'"]

#adjust the references of the positive ligands in the new dataframe
refs = [1, 8, 18, 36]

## YOUR CODE
#Preprocess data
X_dimers = dimers.drop(columns=drop)
X_dimers = min_max_scale(X_dimers)

# Initialize the model
model = KMeansModel(X=X_dimers, k=6, rs=8)

# Run the optimization and get metrics, clusters and per sample silhouette scores for each value of k
metrics, clusters, sil_samples = model.opt(ks=range(2, 15))
# Out:
# 100%|██████████| 13/13 [00:00<00:00, 37.37it/s]

# %% [markdown]
# Plot the metrics

# %%
## YOUR CODE
fig, axes = plt.subplots(1, 3, figsize=(14,4))

for i, metric in enumerate(metrics.columns):

    y = metrics[metric].values
    x = metrics.index
    axes[i].plot(x,y)
    axes[i].set_title(metric)

plt.show()

# %% [markdown]
# In this case, the metrics again do not seem very informative.

# %% [markdown]
# ## Optional
#
# In the original publication, they choose an optimal number of clusters equal to 6. Build a k-Means model with k=6 and fit it with 1000 different random seeds. Then, count how many times each ligand is grouped in the same cluster of the positive ligands.

# %%
## YOUR CODE
#Initialize
best_model = KMeansModel(X=X_dimers, k=6, rs=1)

#adjust the references of the positive ligands in the new dataframe
refs = [1, 8, 18, 36]

# Run the model
best_model.run()

#Run the algorithm
stats_dimers = best_model.stats(ref_ids=refs, k=6)
# Out:
#  10%|▉         | 97/1000 [00:03<00:26, 34.38it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  10%|█         | 101/1000 [00:03<00:25, 34.98it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  10%|█         | 105/1000 [00:03<00:26, 33.42it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  11%|█         | 109/1000 [00:03<00:27, 32.61it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  11%|█▏        | 113/1000 [00:03<00:26, 33.19it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  12%|█▏        | 117/1000 [00:03<00:28, 31.06it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  12%|█▏        | 121/1000 [00:04<00:29, 30.09it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  12%|█▎        | 125/1000 [00:04<00:29, 29.65it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  13%|█▎        | 129/1000 [00:04<00:28, 30.06it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  13%|█▎        | 133/1000 [00:04<00:28, 30.14it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  14%|█▎        | 137/1000 [00:04<00:28, 30.30it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  14%|█▍        | 141/1000 [00:04<00:28, 29.82it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  14%|█▍        | 144/1000 [00:04<00:28, 29.75it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  15%|█▍        | 147/1000 [00:04<00:28, 29.66it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  15%|█▌        | 150/1000 [00:05<00:31, 26.86it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  15%|█▌        | 153/1000 [00:05<00:32, 26.33it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▌        | 156/1000 [00:05<00:31, 26.83it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▌        | 159/1000 [00:05<00:31, 27.02it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  16%|█▋        | 163/1000 [00:05<00:29, 28.32it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  17%|█▋        | 166/1000 [00:05<00:29, 28.06it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  17%|█▋        | 170/1000 [00:05<00:30, 26.97it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  17%|█▋        | 173/1000 [00:05<00:34, 23.86it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  18%|█▊        | 176/1000 [00:06<00:39, 21.06it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  18%|█▊        | 179/1000 [00:06<00:41, 20.01it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  18%|█▊        | 182/1000 [00:06<00:49, 16.57it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  18%|█▊        | 184/1000 [00:06<00:50, 16.07it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▊        | 186/1000 [00:06<00:50, 16.06it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▉        | 188/1000 [00:06<00:52, 15.43it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▉        | 190/1000 [00:07<01:11, 11.33it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  19%|█▉        | 192/1000 [00:07<01:20, 10.02it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|█▉        | 196/1000 [00:07<00:56, 14.29it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|█▉        | 199/1000 [00:07<00:48, 16.62it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  20%|██        | 203/1000 [00:07<00:39, 20.27it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██        | 206/1000 [00:08<00:35, 22.34it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██        | 210/1000 [00:08<00:31, 24.93it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  21%|██▏       | 213/1000 [00:08<00:32, 24.17it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  22%|██▏       | 217/1000 [00:08<00:30, 25.63it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  22%|██▏       | 220/1000 [00:08<00:30, 25.41it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  22%|██▏       | 223/1000 [00:08<00:30, 25.76it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# ...
#  96%|█████████▌| 961/1000 [00:57<00:03, 12.33it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  96%|█████████▋| 963/1000 [00:58<00:02, 12.50it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  96%|█████████▋| 965/1000 [00:58<00:02, 12.39it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 967/1000 [00:58<00:02, 11.83it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 969/1000 [00:58<00:02, 12.18it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 971/1000 [00:58<00:02, 12.09it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  97%|█████████▋| 973/1000 [00:58<00:02, 12.05it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 975/1000 [00:59<00:01, 12.58it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 977/1000 [00:59<00:01, 12.88it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 979/1000 [00:59<00:02, 10.13it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 981/1000 [00:59<00:01, 11.26it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 983/1000 [00:59<00:01, 11.45it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  98%|█████████▊| 985/1000 [00:59<00:01, 11.82it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▊| 987/1000 [01:00<00:01, 11.58it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▉| 989/1000 [01:00<00:00, 11.92it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▉| 991/1000 [01:00<00:00, 11.70it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
#  99%|█████████▉| 993/1000 [01:00<00:00, 11.95it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# 100%|█████████▉| 995/1000 [01:00<00:00, 12.04it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# 100%|█████████▉| 997/1000 [01:00<00:00, 12.26it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# /tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# 100%|█████████▉| 999/1000 [01:01<00:00, 12.00it/s]/tmp/ipython-input-612201913.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats[col] = self.clusters.to_numpy().flatten()
# 100%|██████████| 1000/1000 [01:01<00:00, 16.32it/s]
# /tmp/ipython-input-612201913.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats["Sum"] = stats.sum(axis=1)
# /tmp/ipython-input-612201913.py:144: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stats["Score"] = stats["Sum"] / len(rs_range)

# %% [markdown]
# Now, select the ligands that are grouped in the same clusters than our reference ligands more than 50% of the time.

# %%
## YOUR CODE
#example, take only the ligands whose score is higher than 0.5
dimers[stats_dimers['Score'] > 0.5]
# Out:
#     No. Type  E(HOMO)  E(LUMO)  He8_steric      PA  Q(Pd)  BE(Pd)  \
# 0    15    R -0.17500  0.02350       37.82  247.52 -1.257   30.03
# 1    16    R -0.17267  0.02754       23.38  250.80 -1.200   23.90
# 3    36    R -0.17840  0.02300       19.69  245.86 -1.275   34.79
# 4    37    R -0.17790  0.02220       18.53  246.58 -1.253   35.72
# 5    38    R -0.17610  0.02290       25.93  246.89 -1.267   30.17
# 6    39    R -0.17520  0.02270       16.68  248.60 -1.285   31.24
# 7    40    R -0.17880  0.02253       15.00  245.67 -1.266   35.99
# 8    41    R -0.17250  0.02830       20.96  250.18 -1.200   21.83
# 9    42    R -0.17660  0.02200       30.21  248.25 -1.241   29.09
# 10   43    R -0.17270  0.02600       22.86  250.62 -1.249   33.95
# 11   44    R -0.18216 -0.03031       22.57  247.13 -1.241   35.82
# 12   45    R -0.17060  0.02320       30.37  253.62 -1.194   23.50
# 13   46    R -0.17170  0.02080       28.52  250.35 -1.229   28.69
# 15   49    R -0.17630  0.02320       20.75  249.48 -1.272   34.86
# 16   50    R -0.17300  0.02450       18.49  252.65 -1.250   38.23
# 17   52    R -0.17780 -0.02880       26.39  252.42 -1.240   36.17
# 18   54    R -0.17310  0.01900       19.31  253.11 -1.267   36.45
# 19   55    R -0.16900  0.02060       32.18  256.19 -1.194   23.88
# 21   61    R -0.17130 -0.04080       44.88  254.68 -1.193   17.14
# 27   85   Ar -0.14900 -0.05170        9.74  252.81 -1.214   36.35
# 36  113    R -0.17640 -0.03890       15.93  245.85 -1.275   35.05
# 38  119    R -0.15480 -0.05390       24.38  252.15 -1.233   31.21
# 42  123    R -0.15740 -0.07040       29.17  256.55 -1.176   29.47
# 43  142    R -0.18460 -0.05430       27.66  244.34 -1.176   31.80
# 64  184    R -0.17410 -0.05750       24.90  256.21 -1.239   37.46
#
#     Pd-Cl trans   P-Pd  ...  G_NBO_Pd   G_NBO_P  G_LENGTH_Pd_P  \
# 0         2.379  2.337  ... -0.379685  1.297005       2.312152
# 1         2.382  2.418  ... -0.278010  1.232615       2.413734
# 3         2.379  2.321  ... -0.365385  1.280040       2.317294
# 4         2.380  2.334  ... -0.387150  1.284050       2.346424
# 5         2.378  2.334  ... -0.378850  1.286440       2.316204
# 6         2.379  2.323  ... -0.362885  1.295805       2.300574
# 7         2.379  2.332  ... -0.348165  1.254485       2.325474
# 8         2.379  2.430  ... -0.319535  1.279885       2.358549
# 9         2.379  2.356  ... -0.309540  1.252010       2.353172
# 10        2.379  2.364  ... -0.319980  1.299765       2.352620
# 11        2.376  2.342  ... -0.329330  1.255625       2.366216
# 12        2.378  2.429  ... -0.270445  1.257840       2.400579
# 13        2.378  2.389  ... -0.279355  1.231755       2.409060
# 15        2.378  2.324  ... -0.381075  1.294805       2.320592
# 16        2.380  2.337  ... -0.376735  1.315095       2.348410
# 17        2.377  2.345  ... -0.361815  1.272665       2.309643
# 18        2.377  2.333  ... -0.332865  1.308735       2.349930
# 19        2.378  2.436  ... -0.275160  1.298185       2.406018
# 21        2.380  2.364  ... -0.337645  1.292270       2.371902
# 27        2.367  2.336  ... -0.323820  1.318565       2.324941
# 36        2.375  2.313  ... -0.354985  1.263655       2.344585
# 38        2.373  2.364  ... -0.330635  1.267950       2.374334
# 42        2.374  2.412  ... -0.260775  1.235085       2.398261
# 43        2.375  2.417  ... -0.313500  1.252585       2.418247
# 64        2.375  2.354  ... -0.378215  1.326535       2.344298
#
#     G_LENGTH_Pd_Pd  G_TORSION_Pd_I_I_Pd  G_ORDER_Pd_Pd      PC1'      PC2'  \
# 0         3.226557           103.059842         0.1171 -0.986788  0.414056
# 1         4.305073           174.451579         0.0264  1.198717  1.162347
# 3         3.187955           101.341176         0.1254 -1.135555  0.275201
# 4         3.102411            95.391197         0.1369 -0.904739  0.447820
# 5         3.239473           103.321764         0.1152 -1.040206  0.316550
# 6         3.230060           103.544695         0.1215 -1.275353  0.442776
# 7         4.081617           167.394226         0.0300 -0.363451  0.181895
# 8         4.182134           175.186199         0.0276  0.402554  0.744353
# 9         3.563624           114.587419         0.0813  0.657121  1.031865
# 10        3.525353           114.352055         0.0855 -0.330530  0.977002
# 11        3.424117           107.865086         0.0924 -0.312085  0.603844
# 12        3.492658           107.685463         0.0927  0.727743  1.593900
# 13        3.709239           117.672006         0.0706  0.649510  1.236000
# 15        3.379730           109.862746         0.0962 -1.071356  0.415032
# 16        3.090737            94.752934         0.1399 -0.941889  0.637971
# 17        3.095525            96.862625         0.1375 -0.815093  0.313644
# 18        3.493394           113.883743         0.0870 -0.382255  0.950225
# 19        4.246659           166.430799         0.0311  1.148679  1.617157
# 21        4.174499           179.961486         0.0291  0.963397  0.648156
# 27        3.156178            98.569132         0.1296 -0.738679  1.054474
# 36        3.369690           107.967996         0.1009 -0.484673  0.341689
# 38        3.307408           102.465178         0.1080  0.142621  0.961890
# 42        4.053747           143.899008         0.0527  1.217761  0.584086
# 43        3.538180           110.270443         0.0839  0.734364  1.308740
# 64        3.070816            93.872786         0.1507 -0.630549  0.772650
#
#         PC3'      PC4'
# 0   0.017615 -0.632639
# 1   0.901051 -0.055612
# 3   0.181931 -0.516078
# 4   0.106396 -0.301205
# 5   0.127169 -0.580331
# 6   0.071003 -0.637937
# 7   0.817960 -0.657653
# 8   0.697837 -0.610528
# 9   0.320937 -0.002373
# 10  0.011642 -0.507154
# 11  0.043848  0.154297
# 12  0.056528  0.209290
# 13  0.268430  0.113137
# 15  0.055452 -0.614877
# 16 -0.239464 -0.365896
# 17 -0.295300  0.114543
# 18 -0.268253 -0.606757
# 19  0.294506 -0.101680
# 21 -0.185334 -0.302856
# 27 -0.783943  0.837561
# 36 -0.087634  0.036965
# 38 -0.361800  0.539644
# 42 -0.431804  0.494450
# 43  0.070010  0.709878
# 64 -1.002028  0.542357
#
# [25 rows x 62 columns]

# %% [markdown]
# # 5. Experimental validation

# %% [markdown]
# The second clustering grouped 21 new ligands together with the 4 already known Pd(I) dimer-inducer ligands. These predictions were tested experimentally, and these were the results:
#
# <div align="left">
# <img src="https://github.com/schwallergroup/ai4chem_course/blob/main/notebooks/04%20-%20Unsupervised%20Learning/img/exp_validation.png?raw=1" width="400"/>
# </div>
#
# 8 new dimers were discovered! Quite an impressive result given the low amount of previous data and the poor understanding of ligand-speciation relationship. You can check the structures of the proposed ligands in the SI of the original paper, and realize how different these molecules are. Probably, a human researcher would have discarded them, but ML was able to point out the similarities and provide meaningful counterintuitive experimental suggestions.

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this notebook, you have seen how a simple algorithm like k-means can be very powerful if applied wisely. Researchers at the interface of ML and Chemistry can combine both domains to obtain impressive results. We hope this example motivates you to keep learning more!
#
# Finally, [here](https://github.com/J-Hueffel/PdDimer) is the repo from the original publication, in case you want to check the code. We would also like to acknowledge the [Schoenebeck](https://www.schoenebeck.oc.rwth-aachen.de/) group for this fantastic work.
